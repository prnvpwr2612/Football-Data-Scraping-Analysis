# %%
import pandas as pd

# %%
matches = pd.read_csv("matches.csv", index_col=0)

# %%
matches.head()
# Out:
#          date   time     comp        round  day venue result   gf   ga  \
# 0  2023-08-19  20:45  Serie A  Matchweek 1  Sat  Home      W  2.0  0.0
# 1  2023-08-28  20:45  Serie A  Matchweek 2  Mon  Away      W  2.0  0.0
# 2  2023-09-03  18:30  Serie A  Matchweek 3  Sun  Home      W  4.0  0.0
# 3  2023-09-16  18:00  Serie A  Matchweek 4  Sat  Home      W  5.0  1.0
# 5  2023-09-24  12:30  Serie A  Matchweek 5  Sun  Away      W  1.0  0.0
#
#      opponent  ...  match report  notes    sh   sot  dist   fk pk pkatt  \
# 0       Monza  ...  Match Report    NaN  22.0   3.0  17.2  1.0  0     0
# 1    Cagliari  ...  Match Report    NaN  17.0   3.0  15.9  0.0  0     0
# 2  Fiorentina  ...  Match Report    NaN  20.0  10.0  14.5  1.0  1     1
# 3       Milan  ...  Match Report    NaN  13.0   6.0  15.2  1.0  1     1
# 5      Empoli  ...  Match Report    NaN  23.0   5.0  16.8  0.0  0     0
#
#    season            team
# 0    2022  Internazionale
# 1    2022  Internazionale
# 2    2022  Internazionale
# 3    2022  Internazionale
# 5    2022  Internazionale
#
# [5 rows x 27 columns]

# %%
matches.shape
# Out:
# (1312, 27)

# %%
matches["team"].value_counts()
# Out:
# Internazionale    66
# Napoli            66
# Sassuolo          66
# Torino            66
# Salernitana       66
# Monza             66
# Bologna           66
# Hellas Verona     66
# Atalanta          65
# Fiorentina        65
# Lazio             65
# Roma              65
# Juventus          65
# Lecce             65
# Empoli            65
# Udinese           65
# Milan             65
# Spezia            39
# Cremonese         38
# Sampdoria         38
# Frosinone         28
# Cagliari          28
# Genoa             28
# Name: team, dtype: int64

# %%
matches[matches["team"] == "Milan"].sort_values("date")
# Out:
#           date   time     comp         round  day venue result   gf   ga  \
# 0   2022-08-13  18:30  Serie A   Matchweek 1  Sat  Home      W  4.0  2.0
# 1   2022-08-21  20:45  Serie A   Matchweek 2  Sun  Away      D  1.0  1.0
# 2   2022-08-27  20:45  Serie A   Matchweek 3  Sat  Home      W  2.0  0.0
# 3   2022-08-30  18:30  Serie A   Matchweek 4  Tue  Away      D  0.0  0.0
# 4   2022-09-03  18:00  Serie A   Matchweek 5  Sat  Home      W  3.0  2.0
# ..         ...    ...      ...           ...  ...   ...    ...  ...  ...
# 30  2024-02-03  18:00  Serie A  Matchweek 23  Sat  Away      W  3.0  2.0
# 31  2024-02-11  20:45  Serie A  Matchweek 24  Sun  Home      W  1.0  0.0
# 33  2024-02-18  20:45  Serie A  Matchweek 25  Sun  Away      L  2.0  4.0
# 35  2024-02-25  20:45  Serie A  Matchweek 26  Sun  Home      D  1.0  1.0
# 36  2024-03-01  20:45  Serie A  Matchweek 27  Fri  Away      W  1.0  0.0
#
#      opponent  ...  match report  notes    sh  sot  dist   fk pk pkatt  \
# 0     Udinese  ...  Match Report    NaN  13.0  4.0  19.6  2.0  1     1
# 1    Atalanta  ...  Match Report    NaN  18.0  7.0  20.3  0.0  0     0
# 2     Bologna  ...  Match Report    NaN  19.0  7.0  15.1  0.0  0     0
# 3    Sassuolo  ...  Match Report    NaN  11.0  2.0  18.8  1.0  0     0
# 4       Inter  ...  Match Report    NaN  21.0  5.0  16.7  1.0  0     0
# ..        ...  ...           ...    ...   ...  ...   ...  ... ..   ...
# 30  Frosinone  ...  Match Report    NaN  13.0  5.0  15.4  0.0  0     0
# 31     Napoli  ...  Match Report    NaN  10.0  6.0  18.3  0.0  0     0
# 33      Monza  ...  Match Report    NaN  16.0  6.0  18.6  1.0  0     0
# 35   Atalanta  ...  Match Report    NaN  20.0  6.0  19.0  0.0  0     0
# 36      Lazio  ...  Match Report    NaN  14.0  5.0  18.0  1.0  0     0
#
#     season   team
# 0     2021  Milan
# 1     2021  Milan
# 2     2021  Milan
# 3     2021  Milan
# 4     2021  Milan
# ..     ...    ...
# 30    2022  Milan
# 31    2022  Milan
# 33    2022  Milan
# 35    2022  Milan
# 36    2022  Milan
#
# [65 rows x 27 columns]

# %%
matches["round"].value_counts()
# Out:
# Matchweek 1               40
# Matchweek 15              40
# Matchweek 27              40
# Matchweek 21              40
# Matchweek 26              40
# Matchweek 25              40
# Matchweek 24              40
# Matchweek 23              40
# Matchweek 22              40
# Matchweek 2               40
# Matchweek 19              40
# Matchweek 18              40
# Matchweek 17              40
# Matchweek 16              40
# Matchweek 20              40
# Matchweek 14              40
# Matchweek 13              40
# Matchweek 12              40
# Matchweek 11              40
# Matchweek 10              40
# Matchweek 9               40
# Matchweek 8               40
# Matchweek 7               40
# Matchweek 6               40
# Matchweek 5               40
# Matchweek 4               40
# Matchweek 3               40
# Matchweek 28              30
# Matchweek 29              20
# Matchweek 30              20
# Matchweek 31              20
# Matchweek 32              20
# Matchweek 33              20
# Matchweek 34              20
# Matchweek 35              20
# Matchweek 36              20
# Matchweek 37              20
# Matchweek 38              20
# Relegation tie-breaker     2
# Name: round, dtype: int64

# %%
matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf              float64
# ga              float64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk                int64
# pkatt             int64
# season            int64
# team             object
# dtype: object

# %%
del matches["comp"]

# %%
del matches["notes"]

# %%
matches["date"] = pd.to_datetime(matches["date"])

# %%
matches["target"] = (matches["result"] == "W").astype("int")

# %%
matches
# Out:
#          date   time         round  day venue result   gf   ga    opponent  \
# 0  2023-08-19  20:45   Matchweek 1  Sat  Home      W  2.0  0.0       Monza
# 1  2023-08-28  20:45   Matchweek 2  Mon  Away      W  2.0  0.0    Cagliari
# 2  2023-09-03  18:30   Matchweek 3  Sun  Home      W  4.0  0.0  Fiorentina
# 3  2023-09-16  18:00   Matchweek 4  Sat  Home      W  5.0  1.0       Milan
# 5  2023-09-24  12:30   Matchweek 5  Sun  Away      W  1.0  0.0      Empoli
# ..        ...    ...           ...  ...   ...    ...  ...  ...         ...
# 36 2023-05-08  18:30  Matchweek 34  Mon  Away      L  0.0  2.0     Udinese
# 37 2023-05-15  20:45  Matchweek 35  Mon  Home      D  1.0  1.0      Empoli
# 38 2023-05-20  20:45  Matchweek 36  Sat  Away      L  1.0  5.0       Milan
# 39 2023-05-26  20:45  Matchweek 37  Fri  Home      D  2.0  2.0    Sassuolo
# 40 2023-06-04  18:30  Matchweek 38  Sun  Away      L  0.0  2.0      Napoli
#
#      xg  ...  match report    sh   sot  dist   fk pk pkatt  season  \
# 0   2.7  ...  Match Report  22.0   3.0  17.2  1.0  0     0    2022
# 1   0.9  ...  Match Report  17.0   3.0  15.9  0.0  0     0    2022
# 2   3.7  ...  Match Report  20.0  10.0  14.5  1.0  1     1    2022
# 3   2.6  ...  Match Report  13.0   6.0  15.2  1.0  1     1    2022
# 5   1.6  ...  Match Report  23.0   5.0  16.8  0.0  0     0    2022
# ..  ...  ...           ...   ...   ...   ...  ... ..   ...     ...
# 36  0.9  ...  Match Report  11.0   3.0  21.1  1.0  0     0    2021
# 37  1.3  ...  Match Report  13.0   3.0  16.5  1.0  0     0    2021
# 38  0.6  ...  Match Report   6.0   3.0  17.5  0.0  0     0    2021
# 39  2.2  ...  Match Report  17.0   3.0  15.0  0.0  0     0    2021
# 40  0.6  ...  Match Report   6.0   4.0  10.6  0.0  0     0    2021
#
#               team  target
# 0   Internazionale       1
# 1   Internazionale       1
# 2   Internazionale       1
# 3   Internazionale       1
# 5   Internazionale       1
# ..             ...     ...
# 36       Sampdoria       0
# 37       Sampdoria       0
# 38       Sampdoria       0
# 39       Sampdoria       0
# 40       Sampdoria       0
#
# [1312 rows x 26 columns]

# %%
matches["venue_code"] = matches["venue"].astype("category").cat.codes

# %%
matches["opp_code"] = matches["opponent"].astype("category").cat.codes

# %%
matches["hour"] = matches["time"].str.replace(":.+", "", regex=True).astype("int")

# %%
matches["day_code"] = matches["date"].dt.dayofweek

# %%
matches
# Out:
#          date   time         round  day venue result   gf   ga    opponent  \
# 0  2023-08-19  20:45   Matchweek 1  Sat  Home      W  2.0  0.0       Monza
# 1  2023-08-28  20:45   Matchweek 2  Mon  Away      W  2.0  0.0    Cagliari
# 2  2023-09-03  18:30   Matchweek 3  Sun  Home      W  4.0  0.0  Fiorentina
# 3  2023-09-16  18:00   Matchweek 4  Sat  Home      W  5.0  1.0       Milan
# 5  2023-09-24  12:30   Matchweek 5  Sun  Away      W  1.0  0.0      Empoli
# ..        ...    ...           ...  ...   ...    ...  ...  ...         ...
# 36 2023-05-08  18:30  Matchweek 34  Mon  Away      L  0.0  2.0     Udinese
# 37 2023-05-15  20:45  Matchweek 35  Mon  Home      D  1.0  1.0      Empoli
# 38 2023-05-20  20:45  Matchweek 36  Sat  Away      L  1.0  5.0       Milan
# 39 2023-05-26  20:45  Matchweek 37  Fri  Home      D  2.0  2.0    Sassuolo
# 40 2023-06-04  18:30  Matchweek 38  Sun  Away      L  0.0  2.0      Napoli
#
#      xg  ...   fk  pk  pkatt season            team target venue_code  \
# 0   2.7  ...  1.0   0      0   2022  Internazionale      1          1
# 1   0.9  ...  0.0   0      0   2022  Internazionale      1          0
# 2   3.7  ...  1.0   1      1   2022  Internazionale      1          1
# 3   2.6  ...  1.0   1      1   2022  Internazionale      1          1
# 5   1.6  ...  0.0   0      0   2022  Internazionale      1          0
# ..  ...  ...  ...  ..    ...    ...             ...    ...        ...
# 36  0.9  ...  1.0   0      0   2021       Sampdoria      0          0
# 37  1.3  ...  1.0   0      0   2021       Sampdoria      0          1
# 38  0.6  ...  0.0   0      0   2021       Sampdoria      0          0
# 39  2.2  ...  0.0   0      0   2021       Sampdoria      0          1
# 40  0.6  ...  0.0   0      0   2021       Sampdoria      0          0
#
#     opp_code  hour  day_code
# 0         14    20         5
# 1          2    20         0
# 2          5    18         6
# 3         13    18         5
# 5          4    12         6
# ..       ...   ...       ...
# 36        22    18         0
# 37         4    20         0
# 38        13    20         5
# 39        19    20         4
# 40        15    18         6
#
# [1312 rows x 30 columns]
# Warning: Total number of columns (30) exceeds max_columns (20) limiting to first (20) columns.

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = matches[matches["date"] < '2024-01-01']

# %%
test = matches[matches["date"] > '2024-01-01']

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
error = accuracy_score(test["target"], preds)

# %%
error
# Out:
# 0.6105263157894737

# %%
combined = pd.DataFrame(dict(actual=test["target"], predicted=preds))

# %%
pd.crosstab(index=combined["actual"], columns=combined["predicted"])
# Out:
# predicted   0   1
# actual
# 0          96  23
# 1          51  20

# %%
from sklearn.metrics import precision_score

precision_score(test["target"], preds)
# Out:
# 0.46511627906976744

# %%
grouped_matches = matches.groupby("team")

# %%
group = grouped_matches.get_group("Fiorentina").sort_values("date")

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]
rolling_averages(group, cols, new_cols)
# Out:
#          date   time         round  day venue result   gf   ga       opponent  \
# 5  2022-08-31  18:30   Matchweek 4  Wed  Away      L  0.0  1.0        Udinese
# 6  2022-09-03  15:00   Matchweek 5  Sat  Home      D  1.0  1.0       Juventus
# 8  2022-09-11  15:00   Matchweek 6  Sun  Away      L  1.0  2.0        Bologna
# 10 2022-09-18  15:00   Matchweek 7  Sun  Home      W  2.0  0.0  Hellas Verona
# 11 2022-10-02  18:00   Matchweek 8  Sun  Away      L  0.0  1.0       Atalanta
# ..        ...    ...           ...  ...   ...    ...  ...  ...            ...
# 33 2024-02-11  12:30  Matchweek 24  Sun  Home      W  5.0  1.0      Frosinone
# 34 2024-02-14  19:00  Matchweek 21  Wed  Away      L  0.0  2.0        Bologna
# 35 2024-02-18  15:00  Matchweek 25  Sun  Away      D  1.0  1.0         Empoli
# 36 2024-02-26  20:45  Matchweek 26  Mon  Home      W  2.0  1.0          Lazio
# 37 2024-03-02  20:45  Matchweek 27  Sat  Away      D  0.0  0.0         Torino
#
#      xg  ...  hour  day_code  gf_rolling ga_rolling sh_rolling sot_rolling  \
# 5   0.7  ...    18         2    1.000000   0.666667  19.000000    6.000000
# 6   2.1  ...    15         5    0.000000   0.333333  13.666667    3.000000
# 8   1.3  ...    15         6    0.333333   0.666667  12.666667    3.666667
# 10  2.4  ...    15         6    0.666667   1.333333  13.666667    2.666667
# 11  0.7  ...    18         6    1.333333   1.000000  14.333333    4.666667
# ..  ...  ...   ...       ...         ...        ...        ...         ...
# 33  2.2  ...    12         6    1.333333   2.000000  10.666667    2.666667
# 34  0.9  ...    19         2    2.333333   1.666667  13.666667    4.333333
# 35  0.7  ...    15         6    2.333333   2.000000  13.333333    4.333333
# 36  2.5  ...    20         0    2.000000   1.333333  13.000000    4.333333
# 37  0.6  ...    20         5    1.000000   1.333333  14.000000    4.000000
#
#    dist_rolling  fk_rolling  pk_rolling  pkatt_rolling
# 5     18.700000    0.666667    0.000000       0.000000
# 6     18.533333    0.000000    0.000000       0.000000
# 8     17.933333    0.333333    0.000000       0.333333
# 10    16.833333    0.333333    0.000000       0.333333
# 11    17.633333    0.333333    0.000000       0.666667
# ..          ...         ...         ...            ...
# 33    18.700000    0.333333    0.333333       0.666667
# 34    16.000000    0.333333    0.000000       0.333333
# 35    16.100000    0.333333    0.000000       0.000000
# 36    15.133333    0.333333    0.000000       0.000000
# 37    15.833333    0.333333    0.000000       0.333333
#
# [62 rows x 38 columns]
# Warning: Total number of columns (38) exceeds max_columns (20) limiting to first (20) columns.

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling
# Out:
#                   date   time         round  day venue result   gf   ga  \
# team
# Atalanta 3  2022-09-01  20:45   Matchweek 4  Thu  Home      W  3.0  1.0
#          4  2022-09-05  18:30   Matchweek 5  Mon  Away      W  2.0  0.0
#          5  2022-09-11  12:30   Matchweek 6  Sun  Home      D  1.0  1.0
#          6  2022-09-18  18:00   Matchweek 7  Sun  Away      W  1.0  0.0
#          7  2022-10-02  18:00   Matchweek 8  Sun  Home      W  1.0  0.0
# ...                ...    ...           ...  ...   ...    ...  ...  ...
# Udinese  24 2024-02-03  15:00  Matchweek 23  Sat  Home      D  0.0  0.0
#          25 2024-02-12  20:45  Matchweek 24  Mon  Away      W  1.0  0.0
#          26 2024-02-18  15:00  Matchweek 25  Sun  Home      D  1.0  1.0
#          27 2024-02-24  20:45  Matchweek 26  Sat  Away      L  0.0  2.0
#          28 2024-03-02  15:00  Matchweek 27  Sat  Home      D  1.0  1.0
#
#                 opponent   xg  ...  hour  day_code  gf_rolling ga_rolling  \
# team                           ...
# Atalanta 3        Torino  2.9  ...    20         3    1.333333   0.333333
#          4         Monza  1.9  ...    18         0    1.666667   0.666667
#          5     Cremonese  0.7  ...    12         6    2.000000   0.333333
#          6          Roma  0.2  ...    18         6    2.000000   0.666667
#          7    Fiorentina  1.3  ...    18         6    1.333333   0.333333
# ...                  ...  ...  ...   ...       ...         ...        ...
# Udinese  24        Monza  0.9  ...    15         5    1.333333   2.333333
#          25     Juventus  0.7  ...    20         0    0.666667   1.666667
#          26     Cagliari  1.0  ...    15         6    0.333333   0.666667
#          27        Genoa  0.3  ...    20         5    0.666667   0.333333
#          28  Salernitana  1.8  ...    15         5    0.666667   1.000000
#
#             sh_rolling sot_rolling dist_rolling  fk_rolling  pk_rolling  \
# team
# Atalanta 3   11.666667    4.000000    17.400000    0.000000    0.000000
#          4   12.000000    4.000000    18.866667    0.000000    0.666667
#          5   12.666667    5.333333    17.633333    0.000000    0.666667
#          6   12.333333    5.000000    17.833333    0.333333    0.666667
#          7   10.333333    4.333333    19.933333    0.333333    0.000000
# ...                ...         ...          ...         ...         ...
# Udinese  24  12.000000    5.666667    21.166667    1.000000    0.000000
#          25  15.000000    5.666667    21.966667    0.333333    0.000000
#          26  14.000000    4.000000    21.100000    1.000000    0.000000
#          27  15.333333    3.333333    19.366667    1.000000    0.000000
#          28  10.000000    1.666667    17.766667    1.000000    0.000000
#
#              pkatt_rolling
# team
# Atalanta 3        0.000000
#          4        0.666667
#          5        0.666667
#          6        0.666667
#          7        0.000000
# ...                    ...
# Udinese  24       0.000000
#          25       0.000000
#          26       0.000000
#          27       0.000000
#          28       0.000000
#
# [1243 rows x 38 columns]

# %%
matches_rolling = matches_rolling.droplevel('team')

# %%
matches_rolling
# Out:
#          date   time         round  day venue result   gf   ga     opponent  \
# 3  2022-09-01  20:45   Matchweek 4  Thu  Home      W  3.0  1.0       Torino
# 4  2022-09-05  18:30   Matchweek 5  Mon  Away      W  2.0  0.0        Monza
# 5  2022-09-11  12:30   Matchweek 6  Sun  Home      D  1.0  1.0    Cremonese
# 6  2022-09-18  18:00   Matchweek 7  Sun  Away      W  1.0  0.0         Roma
# 7  2022-10-02  18:00   Matchweek 8  Sun  Home      W  1.0  0.0   Fiorentina
# ..        ...    ...           ...  ...   ...    ...  ...  ...          ...
# 24 2024-02-03  15:00  Matchweek 23  Sat  Home      D  0.0  0.0        Monza
# 25 2024-02-12  20:45  Matchweek 24  Mon  Away      W  1.0  0.0     Juventus
# 26 2024-02-18  15:00  Matchweek 25  Sun  Home      D  1.0  1.0     Cagliari
# 27 2024-02-24  20:45  Matchweek 26  Sat  Away      L  0.0  2.0        Genoa
# 28 2024-03-02  15:00  Matchweek 27  Sat  Home      D  1.0  1.0  Salernitana
#
#      xg  ...  hour  day_code  gf_rolling ga_rolling sh_rolling sot_rolling  \
# 3   2.9  ...    20         3    1.333333   0.333333  11.666667    4.000000
# 4   1.9  ...    18         0    1.666667   0.666667  12.000000    4.000000
# 5   0.7  ...    12         6    2.000000   0.333333  12.666667    5.333333
# 6   0.2  ...    18         6    2.000000   0.666667  12.333333    5.000000
# 7   1.3  ...    18         6    1.333333   0.333333  10.333333    4.333333
# ..  ...  ...   ...       ...         ...        ...        ...         ...
# 24  0.9  ...    15         5    1.333333   2.333333  12.000000    5.666667
# 25  0.7  ...    20         0    0.666667   1.666667  15.000000    5.666667
# 26  1.0  ...    15         6    0.333333   0.666667  14.000000    4.000000
# 27  0.3  ...    20         5    0.666667   0.333333  15.333333    3.333333
# 28  1.8  ...    15         5    0.666667   1.000000  10.000000    1.666667
#
#    dist_rolling  fk_rolling  pk_rolling  pkatt_rolling
# 3     17.400000    0.000000    0.000000       0.000000
# 4     18.866667    0.000000    0.666667       0.666667
# 5     17.633333    0.000000    0.666667       0.666667
# 6     17.833333    0.333333    0.666667       0.666667
# 7     19.933333    0.333333    0.000000       0.000000
# ..          ...         ...         ...            ...
# 24    21.166667    1.000000    0.000000       0.000000
# 25    21.966667    0.333333    0.000000       0.000000
# 26    21.100000    1.000000    0.000000       0.000000
# 27    19.366667    1.000000    0.000000       0.000000
# 28    17.766667    1.000000    0.000000       0.000000
#
# [1243 rows x 38 columns]

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2024-01-01']
    test = data[data["date"] > '2024-01-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    error = precision_score(test["target"], preds)
    return combined, error

# %%
combined, error = make_predictions(matches_rolling, predictors + new_cols)

# %%
error
# Out:
# 0.6097560975609756

# %%
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)

# %%
combined.head(10)
# Out:
#      actual  predicted       date      team   opponent result
# 53        0          0 2024-01-07  Atalanta       Roma      D
# 54        1          0 2024-01-15  Atalanta  Frosinone      W
# 55        1          0 2024-01-27  Atalanta    Udinese      W
# 56        1          0 2024-02-04  Atalanta      Lazio      W
# 57        1          1 2024-02-11  Atalanta      Genoa      W
# 58        1          1 2024-02-17  Atalanta   Sassuolo      W
# 59        0          1 2024-02-25  Atalanta      Milan      D
# 60        0          1 2024-02-28  Atalanta      Inter      L
# 61        0          1 2024-03-03  Atalanta    Bologna      L
# 115       0          0 2024-01-05   Bologna      Genoa      D

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values = {"Atlanta": "Atlanta", "Milan": "Milan", "Monza": "Monza", "Fiorentina": "Fiorentina", "Lecce": "Lecce", "Juventus": "Juventus"}
mapping = MissingDict(**map_values)

# %%
combined["new_team"] = combined["team"].map(mapping)

# %%
merged = combined.merge(combined, left_on=["date", "new_team"], right_on=["date", "opponent"])

# %%
merged
# Out:
#      actual_x  predicted_x       date    team_x   opponent_x result_x  \
# 0           0            0 2024-01-07  Atalanta         Roma        D
# 1           1            0 2024-01-15  Atalanta    Frosinone        W
# 2           1            0 2024-01-27  Atalanta      Udinese        W
# 3           1            0 2024-02-04  Atalanta        Lazio        W
# 4           1            1 2024-02-11  Atalanta        Genoa        W
# ..        ...          ...        ...       ...          ...      ...
# 175         0            0 2024-02-03   Udinese        Monza        D
# 176         1            0 2024-02-12   Udinese     Juventus        W
# 177         0            0 2024-02-18   Udinese     Cagliari        D
# 178         0            0 2024-02-24   Udinese        Genoa        L
# 179         0            0 2024-03-02   Udinese  Salernitana        D
#
#     new_team_x  actual_y  predicted_y       team_y opponent_y result_y  \
# 0     Atalanta         0            0         Roma   Atalanta        D
# 1     Atalanta         0            0    Frosinone   Atalanta        L
# 2     Atalanta         0            0      Udinese   Atalanta        L
# 3     Atalanta         0            0        Lazio   Atalanta        L
# 4     Atalanta         0            0        Genoa   Atalanta        L
# ..         ...       ...          ...          ...        ...      ...
# 175    Udinese         0            0        Monza    Udinese        D
# 176    Udinese         0            1     Juventus    Udinese        L
# 177    Udinese         0            0     Cagliari    Udinese        D
# 178    Udinese         1            0        Genoa    Udinese        W
# 179    Udinese         0            0  Salernitana    Udinese        D
#
#       new_team_y
# 0           Roma
# 1      Frosinone
# 2        Udinese
# 3          Lazio
# 4          Genoa
# ..           ...
# 175        Monza
# 176     Juventus
# 177     Cagliari
# 178        Genoa
# 179  Salernitana
#
# [180 rows x 13 columns]

# %%
merged[(merged["predicted_x"] == 1) & (merged["predicted_y"] ==0)]["actual_x"].value_counts()
# Out:
# 1    19
# 0    14
# Name: actual_x, dtype: int64
